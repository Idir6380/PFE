# %% [markdown]
# ## Import

# %%
# !pip install accelerate bitsandbytes peft transformers joblib tensorboard huggingface_hub[hf_xet]
# Out:
# Collecting accelerate
#   Downloading accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting peft
#   Downloading peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# Collecting transformers
#   Downloading transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Collecting joblib
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting tensorboard
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: huggingface_hub[hf_xet] in /venv/main/lib/python3.12/site-packages (0.30.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /venv/main/lib/python3.12/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /venv/main/lib/python3.12/site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /venv/main/lib/python3.12/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyyaml in /venv/main/lib/python3.12/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /venv/main/lib/python3.12/site-packages (from accelerate) (2.7.0+cu128)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm in /venv/main/lib/python3.12/site-packages (from peft) (4.67.1)
# Requirement already satisfied: filelock in /venv/main/lib/python3.12/site-packages (from transformers) (3.18.0)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 197.2 kB/s eta 0:00:00:--:--
# Requirement already satisfied: requests in /venv/main/lib/python3.12/site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Downloading absl_py-2.3.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.73.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard)
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /venv/main/lib/python3.12/site-packages (from tensorboard) (70.2.0)
# Requirement already satisfied: six>1.9 in /venv/main/lib/python3.12/site-packages (from tensorboard) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /venv/main/lib/python3.12/site-packages (from huggingface_hub[hf_xet]) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /venv/main/lib/python3.12/site-packages (from huggingface_hub[hf_xet]) (4.13.2)
# Collecting hf-xet>=0.1.4 (from huggingface_hub[hf_xet])
#   Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Requirement already satisfied: sympy>=1.13.3 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.61 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.61)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.57 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.57)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.57 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.57)
# Requirement already satisfied: nvidia-cudnn-cu12==9.7.1.26 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (9.7.1.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.3.14 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.3.14)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.41 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.3.3.41)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.55 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (10.3.9.55)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.2.55 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.7.2.55)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.7.53 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.5.7.53)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.55 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.55)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.61 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.61)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.0.11 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (1.13.0.11)
# Requirement already satisfied: triton==3.3.0 in /venv/main/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /venv/main/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.12/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /venv/main/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.12/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/main/lib/python3.12/site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Downloading accelerate-1.7.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 321.4 kB/s eta 0:00:00a 0:00:01
# Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 903.9 kB/s eta 0:00:0000:01:02m
# Downloading peft-0.15.2-py3-none-any.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.1/411.1 kB 630.0 kB/s eta 0:00:00a 0:00:01
# Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 2.0 MB/s eta 0:00:0000:0100:01m
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 4.4 MB/s eta 0:00:0000:0100:01
# Downloading absl_py-2.3.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 5.1 MB/s eta 0:00:00
# Downloading grpcio-1.73.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 5.2 MB/s eta 0:00:00a 0:00:01
# Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 6.5 MB/s eta 0:00:0000:0100:01
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 2.6 MB/s eta 0:00:00ta 0:00:01
# Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 5.3 MB/s eta 0:00:00a 0:00:01
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 8.0 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 7.4 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 3.9 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: werkzeug, tensorboard-data-server, safetensors, regex, protobuf, markdown, joblib, hf-xet, grpcio, absl-py, tensorboard, tokenizers, transformers, bitsandbytes, accelerate, peft
# Successfully installed absl-py-2.3.0 accelerate-1.7.0 bitsandbytes-0.46.0 grpcio-1.73.0 hf-xet-1.1.3 joblib-1.5.1 markdown-3.8 peft-0.15.2 protobuf-6.31.1 regex-2024.11.6 safetensors-0.5.3 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tokenizers-0.21.1 transformers-4.52.4 werkzeug-3.1.3

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /venv/main/lib/python3.12/site-packages (from optuna) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /venv/main/lib/python3.12/site-packages (from optuna) (25.0)
# Collecting sqlalchemy>=1.4.2 (from optuna)
#   Downloading sqlalchemy-2.0.41-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: tqdm in /venv/main/lib/python3.12/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /venv/main/lib/python3.12/site-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /venv/main/lib/python3.12/site-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Collecting greenlet>=1 (from sqlalchemy>=1.4.2->optuna)
#   Downloading greenlet-3.2.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /venv/main/lib/python3.12/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 175.5 kB/s eta 0:00:00a 0:00:01
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 190.3 kB/s eta 0:00:00a 0:00:01
# Downloading sqlalchemy-2.0.41-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 91.4 kB/s eta 0:00:0000:0100:02
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading greenlet-3.2.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (605 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.5/605.5 kB 98.1 kB/s eta 0:00:00a 0:00:01
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 44.9 kB/s eta 0:00:00a 0:00:01m
# Installing collected packages: Mako, greenlet, colorlog, sqlalchemy, alembic, optuna
# Successfully installed Mako-1.3.10 alembic-1.16.1 colorlog-6.9.0 greenlet-3.2.3 optuna-4.3.0 sqlalchemy-2.0.41

# %%
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in /venv/main/lib/python3.12/site-packages (2.7.0+cu128)
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu126/torch-2.7.1%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: torchvision in /venv/main/lib/python3.12/site-packages (0.22.0+cu128)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu126/torchvision-0.22.1%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: torchaudio in /venv/main/lib/python3.12/site-packages (2.7.0+cu128)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu126/torchaudio-2.7.1%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /venv/main/lib/python3.12/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /venv/main/lib/python3.12/site-packages (from torch) (4.13.2)
# Requirement already satisfied: setuptools in /venv/main/lib/python3.12/site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /venv/main/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /venv/main/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /venv/main/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /venv/main/lib/python3.12/site-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /venv/main/lib/python3.12/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /venv/main/lib/python3.12/site-packages (from torch) (2.26.2)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch)
#   Downloading https://download.pytorch.org/whl/triton-3.3.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy in /venv/main/lib/python3.12/site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /venv/main/lib/python3.12/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /venv/main/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# Downloading https://download.pytorch.org/whl/cu126/torch-2.7.1%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl (822.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.0/822.0 MB 6.1 MB/s eta 0:00:00:00:0100:02
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 8.1 MB/s eta 0:00:00:00:0100:01
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 7.9 MB/s eta 0:00:0000:0100:01m
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 649.1 kB/s eta 0:00:00a 0:00:01
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 6.2 MB/s eta 0:00:0000:01m00:02
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 7.4 MB/s eta 0:00:0000:01m0:01m
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading https://download.pytorch.org/whl/cu126/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.7 MB/s eta 0:00:00:00:0100:01
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 10.4 MB/s eta 0:00:0000:0100:01
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 8.0 MB/s eta 0:00:0000:01m0:01m
# Downloading https://download.pytorch.org/whl/cu126/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 11.1 MB/s eta 0:00:0000:0100:01
# Downloading https://download.pytorch.org/whl/cu126/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 18.8 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/triton-3.3.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 9.3 MB/s eta 0:00:00:00:0100:01
# Downloading https://download.pytorch.org/whl/cu126/torchvision-0.22.1%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 8.6 MB/s eta 0:00:0000:01:00:01
# Downloading https://download.pytorch.org/whl/cu126/torchaudio-2.7.1%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.3.0
#     Uninstalling triton-3.3.0:
#       Successfully uninstalled triton-3.3.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.55
#     Uninstalling nvidia-nvtx-cu12-12.8.55:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.55
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.61
#     Uninstalling nvidia-nvjitlink-cu12-12.8.61:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.61
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.55
#     Uninstalling nvidia-curand-cu12-10.3.9.55:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.55
#   Attempting uninstall: nvidia-cufile-cu12
#     Found existing installation: nvidia-cufile-cu12 1.13.0.11
#     Uninstalling nvidia-cufile-cu12-1.13.0.11:
#       Successfully uninstalled nvidia-cufile-cu12-1.13.0.11
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.57
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.57:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.57
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.61
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.61:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.61
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.57
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.57:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.57
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.3.14
#     Uninstalling nvidia-cublas-cu12-12.8.3.14:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.3.14
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.7.53
#     Uninstalling nvidia-cusparse-cu12-12.5.7.53:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.7.53
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.41
#     Uninstalling nvidia-cufft-cu12-11.3.3.41:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.41
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.7.1.26
#     Uninstalling nvidia-cudnn-cu12-9.7.1.26:
#       Successfully uninstalled nvidia-cudnn-cu12-9.7.1.26
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.2.55
#     Uninstalling nvidia-cusolver-cu12-11.7.2.55:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.2.55
#   Attempting uninstall: torch
#     Found existing installation: torch 2.7.0+cu128
#     Uninstalling torch-2.7.0+cu128:
#       Successfully uninstalled torch-2.7.0+cu128
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.22.0+cu128
#     Uninstalling torchvision-0.22.0+cu128:
#       Successfully uninstalled torchvision-0.22.0+cu128
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.7.0+cu128
#     Uninstalling torchaudio-2.7.0+cu128:
#       Successfully uninstalled torchaudio-2.7.0+cu128
# Successfully installed nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 torch-2.7.1+cu126 torchaudio-2.7.1+cu126 torchvision-0.22.1+cu126 triton-3.3.1

# %%
# !pip install xformers
# Out:
# Collecting xformers
#   Downloading xformers-0.0.30-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: numpy in /venv/main/lib/python3.12/site-packages (from xformers) (2.1.2)
# Collecting torch==2.7.0 (from xformers)
#   Downloading torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (4.13.2)
# Requirement already satisfied: setuptools in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (1.13.3)
# Requirement already satisfied: networkx in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (3.3)
# Requirement already satisfied: jinja2 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (3.1.4)
# Requirement already satisfied: fsspec in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /venv/main/lib/python3.12/site-packages (from torch==2.7.0->xformers) (1.11.1.6)
# Collecting triton==3.3.0 (from torch==2.7.0->xformers)
#   Downloading triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.7.0->xformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /venv/main/lib/python3.12/site-packages (from jinja2->torch==2.7.0->xformers) (2.1.5)
# Downloading xformers-0.0.30-cp312-cp312-manylinux_2_28_x86_64.whl (31.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.5/31.5 MB 6.8 MB/s eta 0:00:0000:0100:010m
# Downloading torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (865.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 MB 5.6 MB/s eta 0:00:00:00:010:03m
# Downloading triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 9.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: triton, torch, xformers
#   Attempting uninstall: triton
#     Found existing installation: triton 3.3.1
#     Uninstalling triton-3.3.1:
#       Successfully uninstalled triton-3.3.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.7.1+cu126
#     Uninstalling torch-2.7.1+cu126:
#       Successfully uninstalled torch-2.7.1+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.22.1+cu126 requires torch==2.7.1, but you have torch 2.7.0 which is incompatible.
# torchaudio 2.7.1+cu126 requires torch==2.7.1, but you have torch 2.7.0 which is incompatible.
# Successfully installed torch-2.7.0 triton-3.3.0 xformers-0.0.30

# %%
# !pip install torch-fidelity
# Out:
# Requirement already satisfied: torch-fidelity in /venv/main/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: numpy in /venv/main/lib/python3.12/site-packages (from torch-fidelity) (2.1.2)
# Requirement already satisfied: Pillow in /venv/main/lib/python3.12/site-packages (from torch-fidelity) (11.0.0)
# Requirement already satisfied: scipy in /venv/main/lib/python3.12/site-packages (from torch-fidelity) (1.15.3)
# Requirement already satisfied: torch in /venv/main/lib/python3.12/site-packages (from torch-fidelity) (2.7.1)
# Requirement already satisfied: torchvision in /venv/main/lib/python3.12/site-packages (from torch-fidelity) (0.22.1+cu126)
# Requirement already satisfied: tqdm in /venv/main/lib/python3.12/site-packages (from torch-fidelity) (4.67.1)
# Requirement already satisfied: filelock in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (4.13.2)
# Requirement already satisfied: setuptools in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (1.13.3)
# Requirement already satisfied: networkx in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (3.3)
# Requirement already satisfied: jinja2 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (3.1.4)
# Requirement already satisfied: fsspec in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /venv/main/lib/python3.12/site-packages (from torch->torch-fidelity) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.12/site-packages (from sympy>=1.13.3->torch->torch-fidelity) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /venv/main/lib/python3.12/site-packages (from jinja2->torch->torch-fidelity) (2.1.5)

# %% [markdown]
# ## Drive, HuggingFace, Accelerate

# %%
# %cd ./diffusers
# Out:
# /workspace/PFE/models/diffusers

# %%
# %ls
# Out:
# CITATION.cff        MANIFEST.in    _typos.toml  examples/       src/
# CODE_OF_CONDUCT.md  Makefile       benchmarks/  pyproject.toml  tests/
# CONTRIBUTING.md     PHILOSOPHY.md  docker/      scripts/        utils/
# LICENSE             README.md      docs/        setup.py

# %%
# %cd examples/text_to_image/
# Out:
# /workspace/PFE/models/diffusers/examples/text_to_image

# %% [markdown]
# token = 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

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# %ls
# Out:
# README.md                   train_text_to_image.py
# README_sdxl.md              train_text_to_image_flax.py
# requirements.txt            train_text_to_image_lora.py
# requirements_flax.txt       train_text_to_image_lora_sdxl.py
# requirements_sdxl.txt       train_text_to_image_lora_sdxl_train.py
# test_text_to_image.py       train_text_to_image_sdxl.py
# test_text_to_image_lora.py

# %%
# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
# Remove current diffusers
# !pip uninstall -y diffusers

# Install latest diffusers from GitHub (source install)
# !pip install git+https://github.com/huggingface/diffusers.git
# Out:
# WARNING: Skipping diffusers as it is not installed.
# Collecting git+https://github.com/huggingface/diffusers.git
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-req-build-uu1b3807
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /tmp/pip-req-build-uu1b3807
#   Resolved https://github.com/huggingface/diffusers.git to commit b6f793304437120239d4b942cac623b0ea86039b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting importlib_metadata (from diffusers==0.34.0.dev0)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: filelock in /venv/main/lib/python3.12/site-packages (from diffusers==0.34.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in /venv/main/lib/python3.12/site-packages (from diffusers==0.34.0.dev0) (0.30.2)
# Requirement already satisfied: numpy in /venv/main/lib/python3.12/site-packages (from diffusers==0.34.0.dev0) (2.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /venv/main/lib/python3.12/site-packages (from diffusers==0.34.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /venv/main/lib/python3.12/site-packages (from diffusers==0.34.0.dev0) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /venv/main/lib/python3.12/site-packages (from diffusers==0.34.0.dev0) (0.5.3)
# Requirement already satisfied: Pillow in /venv/main/lib/python3.12/site-packages (from diffusers==0.34.0.dev0) (11.0.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /venv/main/lib/python3.12/site-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /venv/main/lib/python3.12/site-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /venv/main/lib/python3.12/site-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /venv/main/lib/python3.12/site-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /venv/main/lib/python3.12/site-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (4.13.2)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers==0.34.0.dev0)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.12/site-packages (from requests->diffusers==0.34.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /venv/main/lib/python3.12/site-packages (from requests->diffusers==0.34.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.12/site-packages (from requests->diffusers==0.34.0.dev0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/main/lib/python3.12/site-packages (from requests->diffusers==0.34.0.dev0) (2025.4.26)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.34.0.dev0-py3-none-any.whl size=3717905 sha256=779da4ed7d856ddd8fd23475d6363a40ddea82521d27f6461b082bed69ac0694
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jnh84i0d/wheels/23/0f/7d/f97813d265ed0e599a78d83afd4e1925740896ca79b46cccfd
# Successfully built diffusers
# Installing collected packages: zipp, importlib_metadata, diffusers
# Successfully installed diffusers-0.34.0.dev0 importlib_metadata-8.7.0 zipp-3.23.0

# %%
# !pip install -U datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /venv/main/lib/python3.12/site-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /venv/main/lib/python3.12/site-packages (from datasets) (2.1.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-20.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /venv/main/lib/python3.12/site-packages (from datasets) (2.3.0)
# Requirement already satisfied: requests>=2.32.2 in /venv/main/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /venv/main/lib/python3.12/site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /venv/main/lib/python3.12/site-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /venv/main/lib/python3.12/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /venv/main/lib/python3.12/site-packages (from datasets) (6.0.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.12.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /venv/main/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /venv/main/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/main/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /venv/main/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /venv/main/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /venv/main/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading multidict-6.4.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading propcache-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 87.3 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.5 in /venv/main/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 112.5 kB/s eta 0:00:00a 0:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 123.0 kB/s eta 0:00:00a 0:00:01
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 116.8 kB/s eta 0:00:00a 0:00:01
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 131.5 kB/s eta 0:00:0000:0100:01
# Downloading pyarrow-20.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (42.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 8.5 MB/s eta 0:00:0000:0100:01m
# Downloading xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 1.1 MB/s eta 0:00:00:--:--
# Downloading aiohttp-3.12.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.5 MB/s eta 0:00:00a 0:00:01m
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 13.6 MB/s eta 0:00:00
# Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.8/241.8 kB 612.0 kB/s eta 0:00:00--:--
# Downloading multidict-6.4.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading propcache-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.4/224.4 kB 670.7 kB/s eta 0:00:00a 0:00:01
# Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (355 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.6/355.6 kB 566.1 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: xxhash, pyarrow, propcache, multidict, fsspec, frozenlist, dill, attrs, aiohappyeyeballs, yarl, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.12 aiosignal-1.3.2 attrs-25.3.0 datasets-3.6.0 dill-0.3.8 frozenlist-1.7.0 fsspec-2025.3.0 multidict-6.4.4 multiprocess-0.70.16 propcache-0.3.2 pyarrow-20.0.0 xxhash-3.5.0 yarl-1.20.1

# %% [markdown]
# Les meilleurs modeles:
#
# - SD-1.5 \\
# - SD-2.1 \\
# - Realistic_Vision_V6.0 \\
# - SDXL
# - FLUX

# %% [markdown]
# ## SDXL

# %%
import optuna
import subprocess
import joblib
import optuna.visualization as vis
from datetime import datetime
import torch
import sys


# ========== OBJECTIVE FUNCTION ==========
def objective(trial):
    # Hyperparamètres à optimiser
    learning_rate = trial.suggest_categorical("learning_rate", [1e-5, 5e-5, 1e-4, 1e-6])
    lr_scheduler = trial.suggest_categorical("lr_scheduler", ["cosine", "linear"])
    rank = trial.suggest_categorical('rank', [4, 8, 16])
    # Nom unique pour chaque essai
    output_dir = f"optuna-sd-model_bs16_lr{learning_rate}_sched{lr_scheduler}_acc8_{trial.number}"

    # Commande d'entraînement
    command = [
        "accelerate", "launch", "train_text_to_image_lora_sdxl_train.py",
        "--pretrained_model_name_or_path=stabilityai/stable-diffusion-xl-base-1.0",
        "--pretrained_vae_model_name_or_path=madebyollin/sdxl-vae-fp16-fix",
        "--validation_data_dir=/workspace/PFE/VITON-HD-512/k_validations",
        "--train_data_dir=/workspace/PFE/VITON-HD-512/train_images",
        "--caption_column=text",
        "--dataloader_num_workers=8",
        f"--train_batch_size=16",
        "--resolution=512",
        "--max_grad_norm=1",
        f"--gradient_accumulation_steps=8",
        "--num_train_epochs=5",
        "--checkpointing_steps=85",
        "--lr_warmup_steps=0",
        "--mixed_precision=fp16",
        "--seed=1337",
        "--allow_tf32",
        "--use_8bit_adam",
        "--snr_gamma=5.0",
        "--enable_xformers_memory_efficient_attention",
        f"--rank={rank}",
        f"--output_dir={output_dir}",
        f"--lr_scheduler={lr_scheduler}",
        f"--learning_rate={learning_rate}",
        f"--validation_data_output={output_dir}/validation_images",
        #"--max_train_steps=2"
    ]


    try:
        torch.cuda.empty_cache()
        print(f"🔁 Lancement de l'entraînement pour les params : {trial.params}")
        result = subprocess.run(
            command, 
             stdout=subprocess.PIPE,
            #stderr=subprocess.STDOUT,
            text=True,
            check=True)
    except Exception as e:
        print("Erreur lors du nettoyage GPU :", e)

  
    if 'velocity' in result.stdout:
        for line in result.stdout.splitlines():
            if "velocity" in line:
                try:
                    velocity = float(line.split("velocity")[1].split(':')[1])
                    print(f"[Trial {trial.number}] optuna_metric: {velocity}")
                    return velocity
                except Exception as e:
                    print(f"[Trial {trial.number}] Erreur extraction train_loss:", e)

    return float("inf")
            
# ========== LANCER L’OPTIMISATION ==========

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
study_name = f"sdxl_optuna_study_{timestamp}"
study = optuna.create_study(direction="minimize", study_name=study_name)
study.optimize(objective, n_trials=10)
# Sauvegarde du modèle d’étude
joblib.dump(study, f"{study_name}.pkl")
print("\n=============================")
print("💡 Best trial:")
print(study.best_trial)
print("=============================")
# Out:
# [I 2025-05-25 00:44:49,172] A new study created in memory with name: sdxl_optuna_study_20250525_004449
# 🔁 Lancement de l'entraînement pour les params : {'learning_rate': 1e-06, 'lr_scheduler': 'cosine', 'rank': 8}
# 05/25/2025 00:44:58 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'dynamic_thresholding_ratio', 'thresholding', 'variance_type', 'clip_sample_range', 'rescale_betas_zero_snr'} was not found in config. Values will be initialized to default values.
# {'latents_std', 'use_quant_conv', 'latents_mean', 'mid_block_add_attention', 'shift_factor', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at madebyollin/sdxl-vae-fp16-fix.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# {'attention_type', 'dropout', 'reverse_transformer_layers_per_block'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at stabilityai/stable-diffusion-xl-base-1.0.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# 05/25/2025 00:45:11 - INFO - __main__ - ***** Running training *****
# 05/25/2025 00:45:11 - INFO - __main__ -   Num examples = 10805
# 05/25/2025 00:45:11 - INFO - __main__ -   Num Epochs = 5
# 05/25/2025 00:45:11 - INFO - __main__ -   Instantaneous batch size per device = 16
# 05/25/2025 00:45:11 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 128
# 05/25/2025 00:45:11 - INFO - __main__ -   Gradient Accumulation steps = 8
# 05/25/2025 00:45:11 - INFO - __main__ -   Total optimization steps = 425
# Steps:  20%|██        | 85/425 [13:47<47:32,  8.39s/it, lr=9.98e-7, step_loss=0.104]05/25/2025 00:58:59 - INFO - accelerate.accelerator - Saving current state to optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-85
# Model weights saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-85/pytorch_lora_weights.safetensors
# 05/25/2025 00:59:00 - INFO - accelerate.checkpointing - Optimizer state saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-85/optimizer.bin
# 05/25/2025 00:59:00 - INFO - accelerate.checkpointing - Scheduler state saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-85/scheduler.bin
# 05/25/2025 00:59:00 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-85/sampler.bin
# 05/25/2025 00:59:00 - INFO - accelerate.checkpointing - Gradient scaler state saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-85/scaler.pt
# 05/25/2025 00:59:00 - INFO - accelerate.checkpointing - Random states saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-85/random_states_0.pkl
# 05/25/2025 00:59:00 - INFO - __main__ - Saved state to optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-85
# Steps:  20%|██        | 85/425 [13:48<47:32,  8.39s/it, lr=9.98e-7, step_loss=0.072]{'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'sigma_min', 'use_exponential_sigmas', 'use_beta_sigmas', 'timestep_type', 'final_sigmas_type', 'rescale_betas_zero_snr', 'sigma_max'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 52.12it/s]
#
#   0%|          | 0/60 [00:00<?, ?it/s]
#   2%|▏         | 1/60 [00:00<00:23,  2.49it/s]
#   3%|▎         | 2/60 [00:00<00:18,  3.19it/s]
#   5%|▌         | 3/60 [00:00<00:16,  3.42it/s]
#   7%|▋         | 4/60 [00:01<00:15,  3.54it/s]
#   8%|▊         | 5/60 [00:01<00:15,  3.63it/s]
#  10%|█         | 6/60 [00:01<00:13,  3.87it/s]
#  12%|█▏        | 7/60 [00:01<00:13,  4.02it/s]
#  13%|█▎        | 8/60 [00:02<00:13,  3.91it/s]
#  15%|█▌        | 9/60 [00:02<00:12,  3.96it/s]
#  17%|█▋        | 10/60 [00:02<00:11,  4.17it/s]
#  18%|█▊        | 11/60 [00:02<00:11,  4.33it/s]
#  20%|██        | 12/60 [00:03<00:10,  4.46it/s]
#  22%|██▏       | 13/60 [00:03<00:10,  4.55it/s]
#  23%|██▎       | 14/60 [00:03<00:09,  4.62it/s]
#  25%|██▌       | 15/60 [00:03<00:09,  4.68it/s]
#  27%|██▋       | 16/60 [00:03<00:09,  4.71it/s]
#  28%|██▊       | 17/60 [00:04<00:09,  4.72it/s]
#  30%|███       | 18/60 [00:04<00:08,  4.74it/s]
#  32%|███▏      | 19/60 [00:04<00:08,  4.76it/s]
#  33%|███▎      | 20/60 [00:04<00:08,  4.77it/s]
#  35%|███▌      | 21/60 [00:04<00:08,  4.78it/s]
#  37%|███▋      | 22/60 [00:05<00:07,  4.79it/s]
#  38%|███▊      | 23/60 [00:05<00:07,  4.78it/s]
#  40%|████      | 24/60 [00:05<00:07,  4.77it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.78it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.79it/s]
#  45%|████▌     | 27/60 [00:06<00:06,  4.79it/s]
#  47%|████▋     | 28/60 [00:06<00:06,  4.80it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.80it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.80it/s]
#  52%|█████▏    | 31/60 [00:07<00:06,  4.80it/s]
#  53%|█████▎    | 32/60 [00:07<00:05,  4.80it/s]
#  55%|█████▌    | 33/60 [00:07<00:05,  4.80it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.80it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.81it/s]
#  60%|██████    | 36/60 [00:08<00:04,  4.80it/s]
#  62%|██████▏   | 37/60 [00:08<00:04,  4.81it/s]
#  63%|██████▎   | 38/60 [00:08<00:04,  4.80it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.80it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.80it/s]
#  68%|██████▊   | 41/60 [00:09<00:03,  4.80it/s]
#  70%|███████   | 42/60 [00:09<00:03,  4.80it/s]
#  72%|███████▏  | 43/60 [00:09<00:03,  4.81it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.81it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.79it/s]
#  77%|███████▋  | 46/60 [00:10<00:02,  4.78it/s]
#  78%|███████▊  | 47/60 [00:10<00:02,  4.79it/s]
#  80%|████████  | 48/60 [00:10<00:02,  4.79it/s]
#  82%|████████▏ | 49/60 [00:10<00:02,  4.80it/s]
#  83%|████████▎ | 50/60 [00:10<00:02,  4.80it/s]
#  85%|████████▌ | 51/60 [00:11<00:01,  4.81it/s]
#  87%|████████▋ | 52/60 [00:11<00:01,  4.81it/s]
#  88%|████████▊ | 53/60 [00:11<00:01,  4.81it/s]
#  90%|█████████ | 54/60 [00:11<00:01,  4.81it/s]
#  92%|█████████▏| 55/60 [00:12<00:01,  4.81it/s]
#  93%|█████████▎| 56/60 [00:12<00:00,  4.81it/s]
#  95%|█████████▌| 57/60 [00:12<00:00,  4.80it/s]
#  97%|█████████▋| 58/60 [00:12<00:00,  4.77it/s]
#  98%|█████████▊| 59/60 [00:12<00:00,  4.78it/s]
# 100%|██████████| 60/60 [00:13<00:00,  4.59it/s]
# 05/25/2025 00:59:14 - INFO - __main__ - Running validation...
#  Generating images with prompt: A portrait of a plus-size white woman in her thirties, plain background..
#
#   0%|          | 0/60 [00:00<?, ?it/s]
#   2%|▏         | 1/60 [00:00<00:13,  4.48it/s]
#   3%|▎         | 2/60 [00:00<00:12,  4.64it/s]
#   5%|▌         | 3/60 [00:00<00:12,  4.71it/s]
#   7%|▋         | 4/60 [00:00<00:11,  4.75it/s]
#   8%|▊         | 5/60 [00:01<00:11,  4.77it/s]
#  10%|█         | 6/60 [00:01<00:11,  4.79it/s]
#  12%|█▏        | 7/60 [00:01<00:11,  4.80it/s]
#  13%|█▎        | 8/60 [00:01<00:10,  4.81it/s]
#  15%|█▌        | 9/60 [00:01<00:10,  4.82it/s]
#  17%|█▋        | 10/60 [00:02<00:10,  4.83it/s]
#  18%|█▊        | 11/60 [00:02<00:10,  4.83it/s]
#  20%|██        | 12/60 [00:02<00:09,  4.84it/s]
#  22%|██▏       | 13/60 [00:02<00:09,  4.83it/s]
#  23%|██▎       | 14/60 [00:02<00:09,  4.83it/s]
#  25%|██▌       | 15/60 [00:03<00:09,  4.84it/s]
#  27%|██▋       | 16/60 [00:03<00:09,  4.84it/s]
#  28%|██▊       | 17/60 [00:03<00:08,  4.84it/s]
#  30%|███       | 18/60 [00:03<00:08,  4.84it/s]
#  32%|███▏      | 19/60 [00:03<00:08,  4.84it/s]
#  33%|███▎      | 20/60 [00:04<00:08,  4.84it/s]
#  35%|███▌      | 21/60 [00:04<00:08,  4.84it/s]
#  37%|███▋      | 22/60 [00:04<00:07,  4.84it/s]
#  38%|███▊      | 23/60 [00:04<00:07,  4.84it/s]
#  40%|████      | 24/60 [00:04<00:07,  4.84it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.84it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.84it/s]
#  45%|████▌     | 27/60 [00:05<00:06,  4.84it/s]
#  47%|████▋     | 28/60 [00:05<00:06,  4.84it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.79it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.80it/s]
#  52%|█████▏    | 31/60 [00:06<00:06,  4.82it/s]
#  53%|█████▎    | 32/60 [00:06<00:05,  4.82it/s]
#  55%|█████▌    | 33/60 [00:06<00:05,  4.83it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.83it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.84it/s]
#  60%|██████    | 36/60 [00:07<00:04,  4.84it/s]
#  62%|██████▏   | 37/60 [00:07<00:04,  4.84it/s]
#  63%|██████▎   | 38/60 [00:07<00:04,  4.84it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.84it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.84it/s]
#  68%|██████▊   | 41/60 [00:08<00:03,  4.84it/s]
#  70%|███████   | 42/60 [00:08<00:03,  4.84it/s]
#  72%|███████▏  | 43/60 [00:08<00:03,  4.84it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.84it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.84it/s]
#  77%|███████▋  | 46/60 [00:09<00:02,  4
/s]
#  23%|██▎       | 14/60 [00:02<00:09,  4.81it/s]
#  25%|██▌       | 15/60 [00:03<00:09,  4.81it/s]
#  27%|██▋       | 16/60 [00:03<00:09,  4.81it/s]
#  28%|██▊       | 17/60 [00:03<00:08,  4.81it/s]
#  30%|███       | 18/60 [00:03<00:08,  4.80it/s]
#  32%|███▏      | 19/60 [00:03<00:08,  4.80it/s]
#  33%|███▎      | 20/60 [00:04<00:08,  4.81it/s]
#  35%|███▌      | 21/60 [00:04<00:08,  4.80it/s]
#  37%|███▋      | 22/60 [00:04<00:07,  4.80it/s]
#  38%|███▊      | 23/60 [00:04<00:07,  4.79it/s]
#  40%|████      | 24/60 [00:05<00:07,  4.79it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.79it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.80it/s]
#  45%|████▌     | 27/60 [00:05<00:06,  4.80it/s]
#  47%|████▋     | 28/60 [00:05<00:06,  4.80it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.80it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.81it/s]
#  52%|█████▏    | 31/60 [00:06<00:06,  4.81it/s]
#  53%|█████▎    | 32/60 [00:06<00:05,  4.81it/s]
#  55%|█████▌    | 33/60 [00:06<00:05,  4.81it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.81it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.81it/s]
#  60%|██████    | 36/60 [00:07<00:04,  4.81it/s]
#  62%|██████▏   | 37/60 [00:07<00:04,  4.80it/s]
#  63%|██████▎   | 38/60 [00:07<00:04,  4.80it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.80it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.81it/s]
#  68%|██████▊   | 41/60 [00:08<00:03,  4.81it/s]
#  70%|███████   | 42/60 [00:08<00:03,  4.81it/s]
#  72%|███████▏  | 43/60 [00:08<00:03,  4.81it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.81it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.81it/s]
#  77%|███████▋  | 46/60 [00:09<00:02,  4.81it/s]
#  78%|███████▊  | 47/60 [00:09<00:02,  4.81it/s]
#  80%|████████  | 48/60 [00:10<00:02,  4.81it/s]
#  82%|████████▏ | 49/60 [00:10<00:02,  4.81it/s]
#  83%|████████▎ | 50/60 [00:10<00:02,  4.81it/s]
#  85%|████████▌ | 51/60 [00:10<00:01,  4.81it/s]
#  87%|████████▋ | 52/60 [00:10<00:01,  4.80it/s]
#  88%|████████▊ | 53/60 [00:11<00:01,  4.80it/s]
#  90%|█████████ | 54/60 [00:11<00:01,  4.80it/s]
#  92%|█████████▏| 55/60 [00:11<00:01,  4.81it/s]
#  93%|█████████▎| 56/60 [00:11<00:00,  4.81it/s]
#  95%|█████████▌| 57/60 [00:11<00:00,  4.81it/s]
#  97%|█████████▋| 58/60 [00:12<00:00,  4.81it/s]
#  98%|█████████▊| 59/60 [00:12<00:00,  4.81it/s]
# 100%|██████████| 60/60 [00:12<00:00,  4.80it/s]
# 05/25/2025 01:00:43 - INFO - __main__ - Running validation...
#  Generating images with prompt: A portrait of an average white woman in her thirties, plain background..
#
#   0%|          | 0/60 [00:00<?, ?it/s]
#   2%|▏         | 1/60 [00:00<00:13,  4.50it/s]
#   3%|▎         | 2/60 [00:00<00:12,  4.66it/s]
#   5%|▌         | 3/60 [00:00<00:12,  4.72it/s]
#   7%|▋         | 4/60 [00:00<00:11,  4.76it/s]
#   8%|▊         | 5/60 [00:01<00:11,  4.77it/s]
#  10%|█         | 6/60 [00:01<00:11,  4.79it/s]
#  12%|█▏        | 7/60 [00:01<00:11,  4.80it/s]
#  13%|█▎        | 8/60 [00:01<00:10,  4.80it/s]
#  15%|█▌        | 9/60 [00:01<00:10,  4.79it/s]
#  17%|█▋        | 10/60 [00:02<00:10,  4.76it/s]
#  18%|█▊        | 11/60 [00:02<00:10,  4.75it/s]
#  20%|██        | 12/60 [00:02<00:10,  4.76it/s]
#  22%|██▏       | 13/60 [00:02<00:09,  4.77it/s]
#  23%|██▎       | 14/60 [00:02<00:09,  4.75it/s]
#  25%|██▌       | 15/60 [00:03<00:09,  4.77it/s]
#  27%|██▋       | 16/60 [00:03<00:09,  4.78it/s]
#  28%|██▊       | 17/60 [00:03<00:08,  4.80it/s]
#  30%|███       | 18/60 [00:03<00:08,  4.81it/s]
#  32%|███▏      | 19/60 [00:03<00:08,  4.81it/s]
#  33%|███▎      | 20/60 [00:04<00:08,  4.80it/s]
#  35%|███▌      | 21/60 [00:04<00:08,  4.80it/s]
#  37%|███▋      | 22/60 [00:04<00:07,  4.80it/s]
#  38%|███▊      | 23/60 [00:04<00:07,  4.80it/s]
#  40%|████      | 24/60 [00:05<00:07,  4.80it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.80it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.81it/s]
#  45%|████▌     | 27/60 [00:05<00:06,  4.81it/s]
#  47%|████▋     | 28/60 [00:05<00:06,  4.81it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.80it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.77it/s]
#  52%|█████▏    | 31/60 [00:06<00:06,  4.76it/s]
#  53%|█████▎    | 32/60 [00:06<00:05,  4.77it/s]
#  55%|█████▌    | 33/60 [00:06<00:05,  4.78it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.79it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.80it/s]
#  60%|██████    | 36/60 [00:07<00:04,  4.81it/s]
#  62%|██████▏   | 37/60 [00:07<00:04,  4.81it/s]
#  63%|██████▎   | 38/60 [00:07<00:04,  4.82it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.82it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.82it/s]
#  68%|██████▊   | 41/60 [00:08<00:03,  4.82it/s]
#  70%|███████   | 42/60 [00:08<00:03,  4.82it/s]
#  72%|███████▏  | 43/60 [00:08<00:03,  4.82it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.82it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.82it/s]
#  77%|███████▋  | 46/60 [00:09<00:02,  4.82it/s]
#  78%|███████▊  | 47/60 [00:09<00:02,  4.83it/s]
#  80%|████████  | 48/60 [00:10<00:02,  4.83it/s]
#  82%|████████▏ | 49/60 [00:10<00:02,  4.83it/s]
#  83%|████████▎ | 50/60 [00:10<00:02,  4.82it/s]
#  85%|████████▌ | 51/60 [00:10<00:01,  4.82it/s]
#  87%|████████▋ | 52/60 [00:10<00:01,  4.82it/s]
#  88%|████████▊ | 53/60 [00:11<00:01,  4.82it/s]
#  90%|█████████ | 54/60 [00:11<00:01,  4.82it/s]
#  92%|█████████▏| 55/60 [00:11<00:01,  4.82it/s]
#  93%|█████████▎| 56/60 [00:11<00:00,  4.83it/s]
#  95%|█████████▌| 57/60 [00:11<00:00,  4.81it/s]
#  97%|█████████▋| 58/60 [00:12<00:00,  4.79it/s]
#  98%|█████████▊| 59/60 [00:12<00:00,  4.77it/s]
# 100%|██████████| 60/60 [00:12<00:00,  4.79it/s]
# 05/25/2025 01:00:55 - INFO - __main__ - Running validation...
#  Generating images with prompt: A portrait of a pregnant white woman in her thirties, plain background..
#
#   0%|          | 0/60 [00:00<?, ?it/s]
#   2%|▏         | 1/60 [00:00<00:13,  4.36it/s]
#   3%|▎         | 2/60 [00:00<00:12,  4.60it/s]
#   5%|▌         | 3/60 [00:00<00:12,  4.69it/s]
#   7%|▋         | 4/60 [00:00<00:11,  4.74it/s]
#   8%|▊         | 5/60 [00:01<00:11,  4.77it/s]
#  10%|█         | 6/60 [00:01<00:11,  4.80it/s]
#  12%|█▏        | 7/60 [00:01<00:11,  4.81it/s]
#  13%|█▎        | 8/60 [00:01<00:10,  4.81it/s]
#  15%|█▌        | 9/60 [00:01<00:10,  4.82it/s]
#  17%|█▋        | 10/60 [00:02<00:10,  4.82it/s]
#  18%|█▊        | 11/60 [00:02<00:10,  4.81it/s]
#  20%|██        | 12/60 [00:02<00:10,  4.79it/s]
#  22%|██▏       | 13/60 [00:02<00:09,  4.77it/s]
#  23%|██▎       | 14/60 [00:02<00:09,  4.77it/s]
#  25%|██▌       | 15/60 [00:03<00:09,  4.78it/s]
#  27%|██▋       | 16/60 [00:03<00:09,  4.79it/s]
#  28%|██▊       | 17/60 [00:03<00:08,  4.79it/s]
#  30%|███       | 18/60 [00:03<00:08,  4.79it/s]
#  32%|███▏      | 19/60 [00:03<00:08,  4.80it/s]
#  33%|███▎      | 20/60 [00:04<00:08,  4.80it/s]
#  35%|███▌      | 21/60 [00:04<00:08,  4.81it/s]
#  37%|███▋      | 22/60 [00:04<00:07,  4.80it/s]
#  38%|███▊      | 23/60 [00:04<00:07,  4.81it/s]
#  40%|████      | 24/60 [00:05<00:07,  4.81it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.82it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.82it/s]
#  45%|████▌     | 27/60 [00:05<00:06,  4.82it/s]
#  47%|████▋     | 28/60 [00:05<00:06,  4.82it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.82it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.82it/s]
#  52%|█████▏    | 31/60 [00:06<00:06,  4.82it/s]
#  53%|█████▎    | 32/60 [00:06<00:05,  4.83it/s]
#  55%|█████▌    | 33/60 [00:06<00:05,  4.82it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.83it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.83it/s]
#  60%|██████    | 36/60 [00:07<00:04,  4.83it/s]
#  62%|██████▏   | 37/60 [00:07<00:04,  4.83it/s]
#  63%|██████▎   | 38/60 [00:07<00:04,  4.83it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.83it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.82it/s]
#  68%|██████▊   | 41/60 [00:08<00:03,  4.82it/s]
#  70%|███████   | 42/60 [00:08<00:03,  4.82it/s]
#  72%|███████▏  | 43/60 [00:08<00:03,  4.83it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.83it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.82it/s]
#  77%|███████▋  | 46/60 [00:09<00:02,  4.81it/s]
#  78%|███████▊  | 47/60 [00:09<00:02,  4.81it/s]
#  80%|████████  | 48/60 [00:09<00:02,  4.80it/s]
#  82%|████████▏ | 49/60 [00:10<00:02,  4.81it/s]
#  83%|████████▎ | 50/60 [00:10<00:02,  4.81it/s]
#  85%|████████▌ | 51/60 [00:10<00:01,  4.81it/s]
#  87%|████████▋ | 52/60 [00:10<00:01,  4.82it/s]
#  88%|████████▊ | 53/60 [00:11<00:01,  4.82it/s]
#  90%|█████████ | 54/60 [00:11<00:01,  4.83it/s]
#  92%|█████████▏| 55/60 [00:11<00:01,  4.82it/s]
#  93%|█████████▎| 56/60 [00:11<00:00,  4.82it/s]
#  95%|█████████▌| 57/60 [00:11<00:00,  4.82it/s]
#  97%|█████████▋| 58/60 [00:12<00:00,  4.83it/s]
#  98%|█████████▊| 59/60 [00:12<00:00,  4.83it/s]
# 100%|██████████| 60/60 [00:12<00:00,  4.81it/s]
# 05/25/2025 01:01:08 - INFO - __main__ - Running validation...
#  Generating images with prompt: A portrait of a slim asian woman in her twenties, plain background..
# /venv/main/lib/python3.12/site-packages/torch_fidelity/datasets.py:16: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(img.tobytes())).view(height, width, 3)
# Steps:  40%|████      | 170/425 [30:05<35:36,  8.38s/it, lr=9.94e-7, step_loss=0.0479]05/25/2025 01:15:17 - INFO - accelerate.accelerator - Saving current state to optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-170
# Model weights saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-170/pytorch_lora_weights.safetensors
# 05/25/2025 01:15:17 - INFO - accelerate.checkpointing - Optimizer state saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-170/optimizer.bin
# 05/25/2025 01:15:17 - INFO - accelerate.checkpointing - Scheduler state saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-170/scheduler.bin
# 05/25/2025 01:15:17 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-170/sampler.bin
# 05/25/2025 01:15:17 - INFO - accelerate.checkpointing - Gradient scaler state saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-170/scaler.pt
# 05/25/2025 01:15:17 - INFO - accelerate.checkpointing - Random states saved in optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-170/random_states_0.pkl
# 05/25/2025 01:15:17 - INFO - __main__ - Saved state to optuna-sd-model_bs16_lr1e-06_schedcosine_acc8_0/checkpoint-170
# Steps:  40%|████      | 170/425 [30:06<35:36,  8.38s/it, lr=9.94e-7, step_loss=0.141] {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'sigma_min', 'use_exponential_sigmas', 'use_beta_sigmas', 'timestep_type', 'final_sigmas_type', 'rescale_betas_zero_snr', 'sigma_max'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 51.37it/s]
#
#   0%|          | 0/60 [00:00<?, ?it/s]
#   2%|▏         | 1/60 [00:00<00:16,  3.51it/s]
#   3%|▎         | 2/60 [00:00<00:15,  3.64it/s]
#   5%|▌         | 3/60 [00:00<00:15,  3.69it/s]
#   7%|▋         | 4/60 [00:01<00:15,  3.63it/s]
#   8%|▊         | 5/60 [00:01<00:14,  3.68it/s]
#  10%|█         | 6/60 [00:01<00:13,  3.94it/s]
#  12%|█▏        | 7/60 [00:01<00:12,  4.18it/s]
#  13%|█▎        | 8/60 [00:02<00:11,  4.36it/s]
#  15%|█▌        | 9/60 [00:02<00:11,  4.49it/s]
#  17%|█▋        | 10/60 [00:02<00:10,  4.57it/s]
#  18%|█▊        | 11/60 [00:02<00:10,  4.64it/s]
#  20%|██        | 12/60 [00:02<00:10,  4.68it/s]
#  22%|██▏       | 13/60 [00:03<00:09,  4.72it/s]
#  23%|██▎       | 14/60 [00:03<00:09,  4.74it/s]
#  25%|██▌       | 15/60 [00:03<00:09,  4.75it/s]
#  27%|██▋       | 16/60 [00:03<00:09,  4.72it/s]
#  28%|██▊       | 17/60 [00:03<00:09,  4.71it/s]
#  30%|███       | 18/60 [00:04<00:08,  4.72it/s]
#  32%|███▏      | 19/60 [00:04<00:08,  4.74it/s]
#  33%|███▎      | 20/60 [00:04<00:08,  4.75it/s]
#  35%|███▌      | 21/60 [00:04<00:08,  4.76it/s]
#  37%|███▋      | 22/60 [00:04<00:07,  4.77it/s]
#  38%|███▊      | 23/60 [00:05<00:07,  4.78it/s]
#  40%|████      | 24/60 [00:05<00:07,  4.79it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.78it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.79it/s]
#  45%|████▌     | 27/60 [00:05<00:06,  4.79it/s]
#  47%|████▋     | 28/60 [00:06<00:06,  4.67it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.69it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.72it/s]
#  52%|█████▏    | 31/60 [00:06<00:06,  4.74it/s]
#  53%|█████▎    | 32/60 [00:07<00:05,  4.76it/s]
#  55%|█████▌    | 33/60 [00:07<00:05,  4.77it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.77it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.78it/s]
#  60%|██████    | 36/60 [00:07<00:05,  4.79it/s]
#  62%|██████▏   | 37/60 [00:08<00:04,  4.79it/s]
#  63%|██████▎   | 38/60 [00:08<00:04,  4.79it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.78it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.78it/s]
#  68%|██████▊   | 41/60 [00:08<00:03,  4.79it/s]
#  70%|███████   | 42/60 [00:09<00:03,  4.79it/s]
#  72%|███████▏  | 43/60 [00:09<00:03,  4.80it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.79it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.79it/s]
#  77%|███████▋  | 46/60 [00:09<00:02,  4.71it/s]
#  78%|███████▊  | 47/60 [00:10<00:02,  4.70it/s]
#  80%|████████  | 48/60 [00:10<00:02,  4.70it/s]
#  82%|████████▏ | 49/60 [00:10<00:02,  4.70it/s]
#  83%|████████▎ | 50/60 [00:10<00:02,  4.71it/s]
#  85%|████████▌ | 51/60 [00:11<00:01,  4.72it/s]
#  87%|████████▋ | 52/60 [00:11<00:01,  4.63it/s]
#  88%|████████▊ | 53/60 [00:11<00:01,  4.67it/s]
#  90%|█████████ | 54/60 [00:11<00:01,  4.71it/s]
#  92%|█████████▏| 55/60 [00:11<00:01,  4.71it/s]
#  93%|█████████▎| 56/60 [00:12<00:00,  4.71it/s]
#  95%|█████████▌| 57/60 [00:12<00:00,  4.73it/s]
#  97%|█████████▋| 58/60 [00:12<00:00,  4.74it/s]
#  98%|█████████▊| 59/60 [00:12<00:00,  4.76it/s]
# 100%|██████████| 60/60 [00:12<00:00,  4.63it/s]
# 05/25/2025 01:15:32 - INFO - __main__ - Running validation...
#  Generating images with prompt: A portrait of a plus-size white woman in her thirties, plain background..
#
#   0%|          | 0/60 [00:00<?, ?it/s]
#   2%|▏         | 1/60 [00:00<00:13,  4.45it/s]
#   3%|▎         | 2/60 [00:00<00:12,  4.58it/s]
#   5%|▌         | 3/60 [00:00<00:12,  4.67it/s]
#   7%|▋         | 4/60 [00:00<00:11,  4.72it/s]
#   8%|▊         | 5/60 [00:01<00:11,  4.75it/s]
#  10%|█         | 6/60 [00:01<00:11,  4.76it/s]
#  12%|█▏        | 7/60 [00:01<00:11,  4.74it/s]
#  13%|█▎        | 8/60 [00:01<00:10,  4.75it/s]
#  15%|█▌        | 9/60 [00:01<00:10,  4.73it/s]
#  17%|█▋        | 10/60 [00:02<00:10,  4.71it/s]
#  18%|█▊        | 11/60 [00:02<00:10,  4.70it/s]
#  20%|██        | 12/60 [00:02<00:10,  4.70it/s]
#  22%|██▏       | 13/60 [00:02<00:10,  4.67it/s]
#  23%|██▎       | 14/60 [00:02<00:09,  4.68it/s]
#  25%|██▌       | 15/60 [00:03<00:09,  4.58it/s]
#  27%|██▋       | 16/60 [00:03<00:09,  4.62it/s]
#  28%|██▊       | 17/60 [00:03<00:09,  4.65it/s]
#  30%|███       | 18/60 [00:03<00:08,  4.67it/s]
#  32%|███▏      | 19/60 [00:04<00:08,  4.69it/s]
#  33%|███▎      | 20/60 [00:04<00:08,  4.70it/s]
#  35%|███▌      | 21/60 [00:04<00:08,  4.73it/s]
#  37%|███▋      | 22/60 [00:04<00:07,  4.75it/s]
#  38%|███▊      | 23/60 [00:04<00:07,  4.75it/s]
#  40%|████      | 24/60 [00:05<00:07,  4.71it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.66it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.67it/s]
#  45%|████▌     | 27/60 [00:05<00:07,  4.67it/s]
#  47%|████▋     | 28/60 [00:05<00:06,  4.68it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.69it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.70it/s]
#  52%|█████▏    | 31/60 [00:06<00:06,  4.72it/s]
#  53%|█████▎    | 32/60 [00:06<00:05,  4.72it/s]
#  55%|█████▌    | 33/60 [00:07<00:05,  4.69it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.69it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.70it/s]
#  60%|██████    | 36/60 [00:07<00:05,  4.68it/s]
#  62%|██████▏   | 37/60 [00:07<00:04,  4.70it/s]
#  63%|██████▎   | 38/60 [00:08<00:04,  4.72it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.63it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.67it/s]
#  68%|██████▊   | 41/60 [00:08<00:04,  4.72it/s]
#  70%|███████   | 42/60 [00:08<00:03,  4.76it/s]
#  72%|███████▏  | 43/60 [00:09<00:03,  4.78it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.81it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.82it/s]
#  77%|███████▋  | 46/60 [00:09<00:02,  4.83it/s]
#  78%|███████▊  | 47/60 [00:09<00:02,  4.83it/s]
#  80%|████████  | 48/60 [00:10<00:02,  4.83it/s]
#  82%|████████▏ | 49/60 [00:10<00:02,  4.83it/s]
#  83%|████████▎ | 50/60 [00:10<00:02,  4.83it/s]
#  85%|████████▌ | 51/60 [00:10<00:01,  4.84it/s]
#  87%|████████▋ | 52/60 [00:11<00:01,  4.84it/s]
#  88%|████████▊ | 53/60 [00:11<00:01,  4.85it/s]
#  90%|█████████ | 54/60 [00:11<00:01,  4.85it/s]
#  92%|█████████▏| 55/60 [00:11<00:01,  4.86it/s]
#  93%|█████████▎| 56/60 [00:11<00:00,  4.85it/s]
#  95%|█████████▌| 57/60 [00:12<00:00,  4.82it/s]
#  97%|█████████▋| 58/60 [00:12<00:00,  4.81it/s]
#  98%|█████████▊| 59/60 [00:12<00:00,  4.79it/s]
# 100%|██████████| 60/60 [00:12<00:00,  4.74it/s]
# 05/25/2025 01:15:44 - INFO - __main__ - Running validation...
#  Generating images with prompt: A portrait of a slim indian woman in her thirties, plain background..
#
#   0%|          | 0/60 [00:00<?, ?it/s]
#   2%|▏         | 1/60 [00:00<00:13,  4.52it/s]
#   3%|▎         | 2/60 [00:00<00:12,  4.49it/s]
#   5%|▌         | 3/60 [00:00<00:12,  4.64it/s]
#   7%|▋         | 4/60 [00:00<00:11,  4.71it/s]
#   8%|▊         | 5/60 [00:01<00:11,  4.76it/s]
#  10%|█         | 6/60 [00:01<00:11,  4.79it/s]
#  12%|█▏        | 7/60 [00:01<00:11,  4.81it/s]
#  13%|█▎        | 8/60 [00:01<00:10,  4.82it/s]
#  15%|█▌        | 9/60 [00:01<00:10,  4.83it/s]
#  17%|█▋        | 10/60 [00:02<00:10,  4.84it/s]
#  18%|█▊        | 11/60 [00:02<00:10,  4.84it/s]
#  20%|██        | 12/60 [00:02<00:09,  4.85it/s]
#  22%|██▏       | 13/60 [00:02<00:09,  4.85it/s]
#  23%|██▎       | 14/60 [00:02<00:09,  4.84it/s]
#  25%|██▌       | 15/60 [00:03<00:09,  4.84it/s]
#  27%|██▋       | 16/60 [00:03<00:09,  4.85it/s]
#  28%|██▊       | 17/60 [00:03<00:08,  4.85it/s]
#  30%|███       | 18/60 [00:03<00:08,  4.85it/s]
#  32%|███▏      | 19/60 [00:03<00:08,  4.85it/s]
#  33%|███▎      | 20/60 [00:04<00:08,  4.85it/s]
#  35%|███▌      | 21/60 [00:04<00:08,  4.85it/s]
#  37%|███▋      | 22/60 [00:04<00:07,  4.85it/s]
#  38%|███▊      | 23/60 [00:04<00:07,  4.85it/s]
#  40%|████      | 24/60 [00:04<00:07,  4.85it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.85it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.86it/s]
#  45%|████▌     | 27/60 [00:05<00:06,  4.74it/s]
#  47%|████▋     | 28/60 [00:05<00:06,  4.77it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.79it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.82it/s]
#  52%|█████▏    | 31/60 [00:06<00:06,  4.82it/s]
#  53%|█████▎    | 32/60 [00:06<00:05,  4.83it/s]
#  55%|█████▌    | 33/60 [00:06<00:05,  4.80it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.81it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.81it/s]
#  60%|██████    | 36/60 [00:07<00:04,  4.81it/s]
#  62%|██████▏   | 37/60 [00:07<00:04,  4.81it/s]
#  63%|██████▎   | 38/60 [00:07<00:04,  4.81it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.82it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.82it/s]
#  68%|██████▊   | 41/60 [00:08<00:03,  4.82it/s]
#  70%|███████   | 42/60 [00:08<00:03,  4.81it/s]
#  72%|███████▏  | 43/60 [00:08<00:03,  4.82it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.81it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.81it/s]
#  77%|███████▋  | 46/60 [00:09<00:02,  4.81it/s]
#  78%|███████▊  | 47/60 [00:09<00:02,  4.81it/s]
#  80%|████████  | 48/60 [00:09<00:02,  4.81it/s]
#  82%|████████▏ | 49/60 [00:10<00:02,  4.81it/s]
#  83%|████████▎ | 50/60 [00:10<00:02,  4.81it/s]
#  85%|████████▌ | 51/60 [00:10<00:01,  4.70it/s]
#  87%|████████▋ | 52/60 [00:10<00:01,  4.73it/s]
#  88%|████████▊ | 53/60 [00:11<00:01,  4.75it/s]
#  90%|█████████ | 54/60 [00:11<00:01,  4.77it/s]
#  92%|█████████▏| 55/60 [00:11<00:01,  4
#  38%|███▊      | 23/60 [00:05<00:07,  4.64it/s]
#  40%|████      | 24/60 [00:05<00:07,  4.62it/s]
#  42%|████▏     | 25/60 [00:05<00:07,  4.60it/s]
#  43%|████▎     | 26/60 [00:05<00:07,  4.60it/s]
#  45%|████▌     | 27/60 [00:05<00:07,  4.60it/s]
#  47%|████▋     | 28/60 [00:06<00:06,  4.60it/s]
#  48%|████▊     | 29/60 [00:06<00:06,  4.61it/s]
#  50%|█████     | 30/60 [00:06<00:06,  4.61it/s]
#  52%|█████▏    | 31/60 [00:06<00:06,  4.61it/s]
#  53%|█████▎    | 32/60 [00:06<00:06,  4.62it/s]
#  55%|█████▌    | 33/60 [00:07<00:05,  4.63it/s]
#  57%|█████▋    | 34/60 [00:07<00:05,  4.63it/s]
#  58%|█████▊    | 35/60 [00:07<00:05,  4.63it/s]
#  60%|██████    | 36/60 [00:07<00:05,  4.63it/s]
#  62%|██████▏   | 37/60 [00:08<00:04,  4.63it/s]
#  63%|██████▎   | 38/60 [00:08<00:04,  4.62it/s]
#  65%|██████▌   | 39/60 [00:08<00:04,  4.61it/s]
#  67%|██████▋   | 40/60 [00:08<00:04,  4.58it/s]
#  68%|██████▊   | 41/60 [00:08<00:04,  4.60it/s]
#  70%|███████   | 42/60 [00:09<00:03,  4.60it/s]
#  72%|███████▏  | 43/60 [00:09<00:03,  4.60it/s]
#  73%|███████▎  | 44/60 [00:09<00:03,  4.57it/s]
#  75%|███████▌  | 45/60 [00:09<00:03,  4.56it/s]
#  77%|███████▋  | 46/60 [00:10<00:03,  4.56it/s]
#  78%|███████▊  | 47/60 [00:10<00:02,  4.55it/s]
#  80%|████████  | 48/60 [00:10<00:02,  4.55it/s]
#  82%|████████▏ | 49/60 [00:10<00:02,  4.54it/s]
#  83%|████████▎ | 50/60 [00:10<00:02,  4.54it/s]
#  85%|████████▌ | 51/60 [00:11<00:01,  4.55it/s]
#  87%|████████▋ | 52/60 [00:11<00:01,  4.56it/s]
#  88%|████████▊ | 53/60 [00:11<00:01,  4.58it/s]
#  90%|█████████ | 54/60 [00:11<00:01,  4.59it/s]
#  92%|█████████▏| 55/60 [00:11<00:01,  4.60it/s]
#  93%|█████████▎| 56/60 [00:12<00:00,  4.61it/s]
#  95%|█████████▌| 57/60 [00:12<00:00,  4.61it/s]
#  97%|█████████▋| 58/60 [00:12<00:00,  4.62it/s]
#  98%|█████████▊| 59/60 [00:12<00:00,  4.62it/s]
# 100%|██████████| 60/60 [00:13<00:00,  4.60it/s]
# 05/25/2025 14:32:33 - INFO - __main__ - Running validation...
#  Generating images with prompt: A portrait of a slim white woman in her thirties, plain background..
# Model weights saved in optuna-sd-model_bs16_lr5e-05_schedlinear_acc8_9/pytorch_lora_weights.safetensors
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]Instantiating UNet2DConditionModel model under default dtype torch.float16.
# {'attention_type', 'reverse_transformer_layers_per_block', 'dropout'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--stabilityai--stable-diffusion-xl-base-1.0/snapshots/462165984030d82259a11f4367a4eed129e94a7b/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:03<00:21,  3.58s/it]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:03<00:04,  1.03s/it]Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'rescale_betas_zero_snr', 'sigma_min', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'final_sigmas_type', 'use_exponential_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded text_encoder_2 as CLIPTextModelWithProjection from `text_encoder_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.40it/s]
# Loading unet.
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# No LoRA keys associated to CLIPTextModelWithProjection found with the prefix='text_encoder_2'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModelWithProjection related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# Steps: 100%|██████████| 425/425 [1:22:50<00:00, 11.70s/it, lr=4.37e-5, step_loss=0.0518]
# [I 2025-05-25 14:32:52,093] Trial 9 finished with value: 0.4001987049702415 and parameters: {'learning_rate': 5e-05, 'lr_scheduler': 'linear', 'rank': 8}. Best is trial 3 with value: 0.4000728236377763.
# [Trial 9] optuna_metric: 0.4001987049702415
#
# =============================
# 💡 Best trial:
# FrozenTrial(number=3, state=1, values=[0.4000728236377763], datetime_start=datetime.datetime(2025, 5, 25, 4, 51, 33, 172106), datetime_complete=datetime.datetime(2025, 5, 25, 6, 14, 30, 247225), params={'learning_rate': 1e-05, 'lr_scheduler': 'cosine', 'rank': 8}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': CategoricalDistribution(choices=(1e-05, 5e-05, 0.0001, 1e-06)), 'lr_scheduler': CategoricalDistribution(choices=('cosine', 'linear')), 'rank': CategoricalDistribution(choices=(4, 8, 16))}, trial_id=3, value=None)
# =============================

# %%
# ========== VISUALISATION ==========

import optuna.visualization as vis
print("📊 Génération des graphiques Optuna...")
vis.plot_optimization_history(study).write_html("plot_optimization_history.html", include_plotlyjs="cdn")
vis.plot_param_importances(study).write_html("plot_param_importance.html", include_plotlyjs="cdn")
vis.plot_parallel_coordinate(study).write_html("plot_parallel_coordinates.html", include_plotlyjs="cdn")
vis.plot_slice(study).write_html("plot_slice.html", include_plotlyjs="cdn")
vis.plot_contour(study, params=["learning_rate", "gradient_accumulation_steps"]).write_html("plot_contour.html", include_plotlyjs="cdn")
print("✅ Plots sauvegardés en fichiers HTML.")
# Out:
# 📊 Génération des graphiques Optuna...
# ✅ Plots sauvegardés en fichiers HTML.

# %%
command = [
     
        "accelerate", "launch", "train_text_to_image_lora_sdxl_train.py",
        "--pretrained_model_name_or_path=stabilityai/stable-diffusion-xl-base-1.0",
        "--pretrained_vae_model_name_or_path=madebyollin/sdxl-vae-fp16-fix",
        "--validation_data_dir=/workspace/PFE/VITON-HD-512/k_validations/",
        "--train_data_dir=/workspace/PFE/VITON-HD-512/train_images",
        "--early_stopping_patience=15",
        "--early_stopping_metric=FID",
        "--early_stopping_mode=min",
        "--caption_column=text",
        "--dataloader_num_workers=8",
        "--train_batch_size=16",
        #"--resolution=512",
        "--max_grad_norm=1",
        "--gradient_accumulation_steps=8",
        "--num_train_epochs=100",
        "--checkpointing_steps=85",
        "--lr_warmup_steps=0",
        "--mixed_precision=fp16",
        "--seed=1337",
        "--allow_tf32",
        "--use_8bit_adam",
        "--snr_gamma=5.0",
        "--enable_xformers_memory_efficient_attention",
        "--rank=8",
        "--output_dir=final_train",
        "--lr_scheduler=cosine",
        "--learning_rate=1e-5",
        "--validation_data_output=final_train/validation_images",
        "--resume_from_checkpoint=latest",
 ]
shell_command = " ".join(command)
print("lancement de l'entrainement final")
# !{shell_command}
# Out:
# lancement de l'entrainement final
# 06/12/2025 16:19:42 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'variance_type', 'rescale_betas_zero_snr', 'thresholding', 'clip_sample_range', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# {'shift_factor', 'latents_std', 'mid_block_add_attention', 'use_quant_conv', 'use_post_quant_conv', 'latents_mean'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at madebyollin/sdxl-vae-fp16-fix.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# {'attention_type', 'dropout', 'reverse_transformer_layers_per_block'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at stabilityai/stable-diffusion-xl-base-1.0.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Resolving data files: 100%|███████████| 10806/10806 [00:00<00:00, 263543.30it/s]
# 06/12/2025 16:19:57 - INFO - __main__ - ***** Running training *****
# 06/12/2025 16:19:57 - INFO - __main__ -   Num examples = 10805
# 06/12/2025 16:19:57 - INFO - __main__ -   Num Epochs = 100
# 06/12/2025 16:19:57 - INFO - __main__ -   Instantaneous batch size per device = 16
# 06/12/2025 16:19:57 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 128
# 06/12/2025 16:19:57 - INFO - __main__ -   Gradient Accumulation steps = 8
# 06/12/2025 16:19:57 - INFO - __main__ -   Total optimization steps = 8500
# Resuming from checkpoint checkpoint-2890
# 06/12/2025 16:19:57 - INFO - accelerate.accelerator - Loading states from final_train/checkpoint-2890
# 06/12/2025 16:19:57 - INFO - accelerate.checkpointing - All model weights loaded successfully
# 06/12/2025 16:19:58 - INFO - accelerate.checkpointing - All optimizer states loaded successfully
# 06/12/2025 16:19:58 - INFO - accelerate.checkpointing - All scheduler states loaded successfully
# 06/12/2025 16:19:58 - INFO - accelerate.checkpointing - All dataloader sampler states loaded successfully
# 06/12/2025 16:19:58 - INFO - accelerate.checkpointing - GradScaler state loaded successfully
# 06/12/2025 16:19:58 - INFO - accelerate.checkpointing - All random states loaded successfully
# 06/12/2025 16:19:58 - INFO - accelerate.accelerator - Loading in 0 custom states
# Steps:  35%|▎| 2975/8500 [10:01<9:28:34,  6.17s/it, lr=9.95e-6, step_loss=0.057206/12/2025 16:30:00 - INFO - accelerate.accelerator - Saving current state to final_train/checkpoint-2975
# Model weights saved in final_train/checkpoint-2975/pytorch_lora_weights.safetensors
# 06/12/2025 16:30:01 - INFO - accelerate.checkpointing - Optimizer state saved in final_train/checkpoint-2975/optimizer.bin
# 06/12/2025 16:30:01 - INFO - accelerate.checkpointing - Scheduler state saved in final_train/checkpoint-2975/scheduler.bin
# 06/12/2025 16:30:01 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in final_train/checkpoint-2975/sampler.bin
# 06/12/2025 16:30:01 - INFO - accelerate.checkpointing - Gradient scaler state saved in final_train/checkpoint-2975/scaler.pt
# 06/12/2025 16:30:01 - INFO - accelerate.checkpointing - Random states saved in final_train/checkpoint-2975/random_states_0.pkl
# 06/12/2025 16:30:01 - INFO - __main__ - Saved state to final_train/checkpoint-2975
# Steps:  35%|▎| 2975/8500 [10:02<9:28:34,  6.17s/it, lr=9.95e-6, step_loss=0.158]{'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'sigma_min', 'rescale_betas_zero_snr', 'final_sigmas_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'timestep_type', 'sigma_max'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00, 59.10it/s]
# generating34
# /venv/main/lib/python3.12/site-packages/torch_fidelity/datasets.py:16: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(img.tobytes())).view(height, width, 3)
# 06/12/2025 16:57:57 - INFO - accelerate.accelerator - Saving current state to final_train/best_model
# Model weights saved in final_train/best_model/pytorch_lora_weights.safetensors
# 06/12/2025 16:57:58 - INFO - accelerate.checkpointing - Optimizer state saved in final_train/best_model/optimizer.bin
# 06/12/2025 16:57:58 - INFO - accelerate.checkpointing - Scheduler state saved in final_train/best_model/scheduler.bin
# 06/12/2025 16:57:58 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in final_train/best_model/sampler.bin
# 06/12/2025 16:57:58 - INFO - accelerate.checkpointing - Gradient scaler state saved in final_train/best_model/scaler.pt
# 06/12/2025 16:57:58 - INFO - accelerate.checkpointing - Random states saved in final_train/best_model/random_states_0.pkl
# 06/12/2025 16:57:58 - INFO - __main__ - Saved best model in epoch 34 to final_train/best_model
# Steps:  36%|▎| 3060/8500 [48:03<9:23:11,  6.21s/it, lr=9.95e-6, step_loss=0.102]06/12/2025 17:08:02 - INFO - accelerate.accelerator - Saving current state to final_train/checkpoint-3060
# Model weights saved in final_train/checkpoint-3060/pytorch_lora_weights.safetensors
# 06/12/2025 17:08:02 - INFO - accelerate.checkpointing - Optimizer state saved in final_train/checkpoint-3060/optimizer.bin
# 06/12/2025 17:08:02 - INFO - accelerate.checkpointing - Scheduler state saved in final_train/checkpoint-3060/scheduler.bin
# 06/12/2025 17:08:02 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in final_train/checkpoint-3060/sampler.bin
# 06/12/2025 17:08:02 - INFO - accelerate.checkpointing - Gradient scaler state saved in final_train/checkpoint-3060/scaler.pt
# 06/12/2025 17:08:02 - INFO - accelerate.checkpointing - Random states saved in final_train/checkpoint-3060/random_states_0.pkl
# 06/12/2025 17:08:02 - INFO - __main__ - Saved state to final_train/checkpoint-3060
# Steps:  36%|▎| 3060/8500 [48:04<9:23:11,  6.21s/it, lr=9.95e-6, step_loss=0.106]{'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'sigma_min', 'rescale_betas_zero_snr', 'final_sigmas_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'timestep_type', 'sigma_max'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00, 57.44it/s]
# generating35
# 06/12/2025 17:36:18 - INFO - accelerate.accelerator - Saving current state to final_train/best_model
# Model weights saved in final_train/best_model/pytorch_lora_weights.safetensors
# 06/12/2025 17:36:19 - INFO - accelerate.checkpointing - Optimizer state saved in final_train/best_model/optimizer.bin
# 06/12/2025 17:36:19 - INFO - accelerate.checkpointing - Scheduler state saved in final_train/best_model/scheduler.bin
# 06/12/2025 17:36:19 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in final_train/best_model/sampler.bin
# 06/12/2025 17:36:19 - INFO - accelerate.checkpointing - Gradient scaler state saved in final_train/best_model/scaler.pt
# 06/12/2025 17:36:19 - INFO - accelerate.checkpointing - Random states saved in final_train/best_model/random_states_0.pkl
# 06/12/2025 17:36:19 - INFO - __main__ - Saved best model in epoch 35 to final_train/best_model
# Steps:  37%|▎| 3145/8500 [1:26:24<9:10:28,  6.17s/it, lr=9.95e-6, step_loss=0.0806/12/2025 17:46:22 - INFO - accelerate.accelerator - Saving current state to final_train/checkpoint-3145
# Model weights saved in final_train/checkpoint-3145/pytorch_lora_weights.safetensors
# 06/12/2025 17:46:23 - INFO - accelerate.checkpointing - Optimizer state saved in final_train/checkpoint-3145/optimizer.bin
# 06/12/2025 17:46:23 - INFO - accelerate.checkpointing - Scheduler state saved in final_train/checkpoint-3145/scheduler.bin
# 06/12/2025 17:46:23 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in final_train/checkpoint-3145/sampler.bin
# 06/12/2025 17:46:23 - INFO - accelerate.checkpointing - Gradient scaler state saved in final_train/checkpoint-3145/scaler.pt
# 06/12/2025 17:46:23 - INFO - accelerate.checkpointing - Random states saved in final_train/checkpoint-3145/random_states_0.pkl
# 06/12/2025 17:46:23 - INFO - __main__ - Saved state to final_train/checkpoint-3145
# Steps:  37%|▎| 3145/8500 [1:26:24<9:10:28,  6.17s/it, lr=9.95e-6, step_loss=0.05{'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'sigma_min', 'rescale_betas_zero_snr', 'final_sigmas_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'timestep_type', 'sigma_max'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00, 55.53it/s]
# generating36
# 06/12/2025 18:14:23 - INFO - __main__ - No improvement in FID. Patience: 1/15
# Steps:  38%|▍| 3230/8500 [2:04:25<8:58:33,  6.13s/it, lr=9.94e-6, step_loss=0.0506/12/2025 18:24:23 - INFO - accelerate.accelerator - Saving current state to final_train/checkpoint-3230
# Model weights saved in final_train/checkpoint-3230/pytorch_lora_weights.safetensors
# 06/12/2025 18:24:24 - INFO - accelerate.checkpointing - Optimizer state saved in final_train/checkpoint-3230/optimizer.bin
# 06/12/2025 18:24:24 - INFO - accelerate.checkpointing - Scheduler state saved in final_train/checkpoint-3230/scheduler.bin
# 06/12/2025 18:24:24 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in final_train/checkpoint-3230/sampler.bin
# 06/12/2025 18:24:24 - INFO - accelerate.checkpointing - Gradient scaler state saved in final_train/checkpoint-3230/scaler.pt
# 06/12/2025 18:24:24 - INFO - accelerate.checkpointing - Random states saved in final_train/checkpoint-3230/random_states_0.pkl
# 06/12/2025 18:24:24 - INFO - __main__ - Saved state to final_train/checkpoint-3230
# Steps:  38%|▍| 3230/8500 [2:04:26<8:58:33,  6.13s/it, lr=9.94e-6, step_loss=0.12{'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'sigma_min', 'rescale_betas_zero_snr', 'final_sigmas_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'timestep_type', 'sigma_max'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00, 59.47it/s]
# generating37
# 06/12/2025 18:52:02 - INFO - __main__ - No improvement in FID. Patience: 2/15
# Steps:  39%|▍| 3315/8500 [2:42:03<8:47:48,  6.11s/it, lr=9.94e-6, step_loss=0.0906/12/2025 19:02:01 - INFO - accelerate.accelerator - Saving current state to final_train/checkpoint-3315
# Model weights saved in final_train/checkpoint-3315/pytorch_lora_weights.safetensors
# 06/12/2025 19:02:02 - INFO - accelerate.checkpointing - Optimizer state saved in final_train/checkpoint-3315/optimizer.bin
# 06/12/2025 19:02:02 - INFO - accelerate.checkpointing - Scheduler state saved in final_train/checkpoint-3315/scheduler.bin
# 06/12/2025 19:02:02 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in final_train/checkpoint-3315/sampler.bin
# 06/12/2025 19:02:02 - INFO - accelerate.checkpointing - Gradient scaler state saved in final_train/checkpoint-3315/scaler.pt
# 06/12/2025 19:02:02 - INFO - accelerate.checkpointing - Random states saved in final_train/checkpoint-3315/random_states_0.pkl
# 06/12/2025 19:02:02 - INFO - __main__ - Saved state to final_train/checkpoint-3315
# Steps:  39%|▍| 3315/8500 [2:42:03<8:47:48,  6.11s/it, lr=9.94e-6, step_loss=0.03{'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'sigma_min', 'rescale_betas_zero_snr', 'final_sigmas_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'timestep_type', 'sigma_max'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00, 59.31it/s]
# generating38
# 06/12/2025 19:30:17 - INFO - __main__ - No improvement in FID. Patience: 3/15
# Steps:  39%|▍| 3316/8500 [3:10:29<741:50:33, 515.17s/it, lr=9.94e-6, step_loss=0^C
# Traceback (most recent call last):
#   File "/workspace/PFE/models/diffusers/examples/text_to_image/train_text_to_image_lora_sdxl_train.py", line 1521, in <module>
#     main(args)
#   File "/workspace/PFE/models/diffusers/examples/text_to_image/train_text_to_image_lora_sdxl_train.py", line 1254, in main
#     accelerator.backward(loss)
#   File "/venv/main/lib/python3.12/site-packages/accelerate/accelerator.py", line 2469, in backward
#     self.scaler.scale(loss).backward(**kwargs)
#   File "/venv/main/lib/python3.12/site-packages/torch/_tensor.py", line 648, in backward
#     torch.autograd.backward(
#   File "/venv/main/lib/python3.12/site-packages/torch/autograd/__init__.py", line 353, in backward
#     _engine_run_backward(
#   File "/venv/main/lib/python3.12/site-packages/torch/autograd/graph.py", line 824, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !pip install bitsandbytes

# %%
# %ls /workspace/PFE/VITON-HD-512/k_validations/
# Out:
# validation_0/  validation_2/  validation_4/  validation_6/  validation_8/
# validation_1/  validation_3/  validation_5/  validation_7/  validation_9/
